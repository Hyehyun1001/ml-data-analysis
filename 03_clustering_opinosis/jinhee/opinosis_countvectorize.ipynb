# %%
import pandas as pd
import glob, os
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 700)


# 아래는 제 컴퓨터에서 압축 파일을 풀어 놓은 디렉터리이니, 여러분의 디렉터리를 설정해 주세요  
path = r'C:\big21\ml-dev\data\topics'
# path로 지정한 디렉터리 밑에 있는 모든 .data 파일들의 파일명을 리스트로 취합
all_files = glob.glob(os.path.join(path, "*.data"))    
filename_list = []
opinion_text = []


# 개별 파일들의 파일명은 filename_list 리스트로 취합,
# 개별 파일들의 파일 내용은 DataFrame 로딩 후 다시 string으로 변환하여 opinion_text 리스트로 취합
for file_ in all_files:
    # 개별 파일을 읽어서 DataFrame으로 생성
    df = pd.read_table(file_,index_col=None, header=0,encoding='latin1')
   
    # 절대경로로 주어진 file 명을 가공. 만일 Linux에서 수행시에는 아래 \\를 / 변경.
    # 맨 마지막 .data 확장자도 제거
    filename_ = file_.split('\\')[-1]
    filename = filename_.split('.')[0]


    # 파일명 리스트와 파일 내용 리스트에 파일명과 파일 내용을 추가.
    filename_list.append(filename)
    opinion_text.append(df.to_string())


# 파일명 리스트와 파일 내용 리스트를  DataFrame으로 생성
document_df = pd.DataFrame({'filename':filename_list, 'opinion_text':opinion_text})
document_df.head()
# Out:
#                          filename  \
# 0   accuracy_garmin_nuvi_255W_gps
# 1  bathroom_bestwestern_hotel_sfo
# 2      battery-life_amazon_kindle
# 3      battery-life_ipod_nano_8gb
# 4     battery-life_netbook_1005ha
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text
# 0                                                                                                                                                                                                                                                                 , and is very, very accurate .\n0                                                                                                                                                                           but for the most part, we find that the Garmin software provides accurate directions, whereever we intend to go .\n1                                                                                                              This functi...
# 1                                                                                                                                                                                                                                                The room was not overly big, but clean and very comfortable beds, a great shower and very clean bathrooms .\n0                                                                                                                                                                                                                          The second room was smaller, with a very inconvenient bathroom layout, but at least it was quieter and we were able to sleep .\n1 ...
# 2                                                                                                                                                                                                               After I plugged it in to my USB hub on my computer to charge the battery the charging cord design is very clever !\n0                                                                                                                                     After you have paged tru a 500, page book one, page, at, a, time to get from Chapter 2 to Chapter 15, see how excited you are about a low battery and all the time it took to get there !\n1                                                     ...
# 3                                                                                                                                                                                                                                                                                                 short battery life  I moved up from an 8gb .\n0                                                                                                                                                                                                                                                                                            I love this ipod except for the battery life .\n1                             ...
# 4                                                                                                                                                                                                                                                                                                                  6GHz 533FSB cpu, glossy display, 3, Cell 23Wh Li, ion Battery  , and a 1 .\n0                                                                                                                                                                                                                                                                                              Not to mention that as of now...

# %%
import pandas as pd
import re
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from collections import Counter

# %%
def text_cleaning(text):
    
    # 소문자로 변환
    text = text.lower()
    
    # 영문자와 공백을 제외한 문자 제거
    text = re.sub(r'[^a-z\s]', ' ', text)
    
    # 여러 개의 공백을 하나로 변경
    text = re.sub(r'\s+', ' ', text)
    
    return text.strip()

# %%
# 원문 보관 (혹시모를 상황을 대비)
document_df['original_text'] = document_df['opinion_text']

#소문자 / 영문자/공백/여러개공백 처리
document_df['opinion_text'] = document_df['opinion_text'].apply(text_cleaning)

# 토크나이즈(각 단어들로 구분)
document_df['opinion_text'] = document_df['opinion_text'].apply(word_tokenize)

# 불용어 세팅
stop_words = set(stopwords.words('english'))

# 불용어 정리
document_df['opinion_text'] = document_df['opinion_text'].apply(
    lambda tokens: [
        word for word in tokens
        if word not in stop_words
    ]
)

# 클렌징 및 토큰화 후, 최종 확인
document_df[['opinion_text']].head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   opinion_text
# 0  [accurate, part, find, garmin, software, provides, accurate, directions, whereever, intend, go, function, accurate, leave, battery, mode, say, stop, cracker, barrell, lunch, play, one, trangle, games, tees, provides, immediate, alternatives, route, online, map, program, inaccurate, blocked, obstacle, used, gps, units, well, gps, built, cars, day, nothing, beats, accuracy, garmin, gps, got, point, point, b, accuracy, everytime, yet, disappoint, getting, everywhere, accuracy, stars, honest, accurate, review, please, read, aside, every, destination, thrown, accurate, closing, fantastic, gps, nice, features, accurate, directions, plus, always, heard, quirks, gps, accurate, pois, etc, destina...
# 1  [room, overly, big, clean, comfortable, beds, great, shower, clean, bathrooms, second, room, smaller, inconvenient, bathroom, layout, least, quieter, able, sleep, large, comfortable, room, wonderful, bathroom, rooms, nice, comfy, bed, clean, bathroom, bathroom, spacious, clean, bathroom, single, sink, large, room, standard, nice, motel, room, like, bathroom, seemed, upgraded, remember, room, quite, small, perfectly, formed, super, bathroom, could, eat, bathroom, floor, clean, bathroom, door, thing, making, bathroom, seem, slightly, larger, bathroom, spotless, nicely, appointed, rooms, exceptionally, clean, also, bathrooms, bathroom, clean, bed, comfy, provide, great, aveda, products, bat...
# 2  [plugged, usb, hub, computer, charge, battery, charging, cord, design, clever, paged, tru, page, book, one, page, time, get, chapter, chapter, see, excited, low, battery, time, took, get, user, replaceable, battery, unless, buy, extended, warranty, year, pay, plus, shipping, send, device, amazon, kindle, replaced, battery, changed, fact, kindle, sd, card, capability, battery, user, serviceable, issue, things, like, buttons, made, easy, accidentally, turn, pages, separate, cursor, side, could, select, lines, sometimes, hard, see, occasionally, awkward, menus, case, practically, forced, remove, use, sometimes, pulled, battery, door, issue, battery, door, opening, thus, solved, amazon, went...
# 3  [short, battery, life, moved, gb, love, ipod, except, battery, life, long, battery, scratch, resistant, battery, drains, even, use, wonder, battery, seems, drain, using, even, sliding, top, control, button, shutting, great, car, light, portable, good, quality, long, battery, scratch, resistant, g, lies, mature, ipod, many, steps, wiser, able, one, year, old, ipod, gains, many, incremental, improvements, including, brighter, screen, better, video, battery, life, probably, appealing, aspect, tantalizing, price, points, gb, version, huge, gb, version, gb, better, battery, life, rated, battery, dummie, proof, love, color, ipod, battery, life, amazing, definitely, need, get, case, wanted, get...
# 4  [ghz, fsb, cpu, glossy, display, cell, wh, li, ion, battery, mention, asus, sell, spare, cell, li, ion, battery, also, features, n, cpu, cell, wh, li, ion, battery, mp, webcam, cell, wh, li, ion, battery, whopping, realistic, battery, numbers, battery, life, using, wifi, email, word, processing, youtube, web, surfing, eee, super, hybrid, engine, utility, lets, users, overclock, underclock, eee, pc, boost, performance, provide, better, battery, life, depending, immediate, requirements, things, like, point, must, push, micro, sized, right, angle, end, ac, adapter, snaps, place, battery, may, charge, addition, ac, adapter, get, quite, hot, actively, charging, battery, asus, clearly, mention...

# %%
#단어 빈도수 체크에 대한 함수

from collections import Counter
from nltk.tokenize import word_tokenize

for index, row in document_df.iterrows():
    
    # 클렌징된 텍스트 가져오기
    text = row['opinion_text']
    
    # 단어 빈도 계산
    word_counts = Counter(text)
    
    print(f"===== {row['filename']} =====")
    print(word_counts.most_common(30))
    print()
# Out:
# ===== accuracy_garmin_nuvi_255W_gps =====
# [('accurate', 48), ('accuracy', 13), ('gps', 12), ('directions', 11), ('easy', 9), ('map', 7), ('use', 7), ('used', 6), ('point', 6), ('time', 6), ('speed', 6), ('garmin', 5), ('destination', 5), ('always', 5), ('good', 5), ('unit', 5), ('turn', 5), ('one', 4), ('stars', 4), ('nice', 4), ('pretty', 4), ('arrival', 4), ('w', 4), ('maps', 4), ('street', 4), ('tell', 4), ('roads', 4), ('find', 3), ('route', 3), ('inaccurate', 3)]
#
# ===== bathroom_bestwestern_hotel_sfo =====
# [('bathroom', 79), ('room', 36), ('clean', 23), ('bathrooms', 12), ('rooms', 12), ('nice', 12), ('small', 12), ('large', 10), ('sink', 10), ('also', 9), ('comfortable', 8), ('shower', 8), ('bed', 7), ('door', 7), ('good', 7), ('big', 6), ('well', 6), ('plenty', 6), ('quite', 5), ('little', 5), ('adequate', 5), ('enough', 5), ('hotel', 5), ('us', 5), ('space', 5), ('beds', 4), ('thing', 4), ('toilet', 4), ('basin', 4), ('one', 4)]
#
# ===== battery-life_amazon_kindle =====
# [('battery', 95), ('life', 29), ('kindle', 23), ('charge', 13), ('hours', 12), ('wireless', 10), ('time', 9), ('power', 8), ('user', 7), ('like', 7), ('could', 7), ('use', 7), ('reading', 7), ('k', 7), ('plus', 6), ('even', 6), ('longer', 6), ('days', 6), ('lasts', 6), ('charging', 5), ('device', 5), ('extra', 5), ('thing', 5), ('light', 5), ('screen', 5), ('seems', 5), ('long', 5), ('last', 5), ('replaceable', 4), ('extended', 4)]
#
# ===== battery-life_ipod_nano_8gb =====
# [('battery', 70), ('life', 39), ('ipod', 19), ('great', 14), ('long', 13), ('use', 11), ('easy', 9), ('good', 8), ('short', 7), ('last', 7), ('like', 6), ('thing', 6), ('nano', 6), ('gb', 5), ('love', 5), ('seems', 5), ('quality', 5), ('one', 5), ('new', 5), ('time', 5), ('lasts', 5), ('first', 5), ('gen', 5), ('scratch', 4), ('resistant', 4), ('screen', 4), ('video', 4), ('christmas', 4), ('apple', 4), ('replace', 4)]
#
# ===== battery-life_netbook_1005ha =====
# [('battery', 356), ('life', 172), ('hours', 41), ('netbook', 37), ('long', 35), ('charge', 32), ('great', 29), ('get', 23), ('asus', 21), ('power', 21), ('time', 21), ('hour', 20), ('computer', 20), ('use', 18), ('one', 17), ('screen', 17), ('machine', 15), ('charger', 15), ('eee', 14), ('much', 14), ('would', 14), ('using', 13), ('performance', 13), ('better', 13), ('charging', 13), ('full', 13), ('laptop', 13), ('cell', 12), ('really', 12), ('ha', 12)]
#
# ===== buttons_amazon_kindle =====
# [('buttons', 94), ('button', 84), ('page', 57), ('next', 29), ('kindle', 26), ('press', 17), ('much', 16), ('like', 16), ('one', 13), ('way', 13), ('hit', 12), ('easy', 12), ('use', 12), ('hard', 11), ('time', 10), ('size', 10), ('pages', 10), ('screen', 10), ('device', 10), ('k', 10), ('keyboard', 10), ('turn', 9), ('need', 9), ('hold', 9), ('accidentally', 9), ('previous', 9), ('new', 9), ('reading', 8), ('without', 8), ('bit', 8)]
#
# ===== comfort_honda_accord_2008 =====
# [('comfortable', 95), ('comfort', 46), ('car', 37), ('seats', 30), ('seat', 28), ('drive', 23), ('ride', 22), ('uncomfortable', 21), ('great', 19), ('interior', 17), ('accord', 17), ('vehicle', 12), ('driver', 12), ('better', 10), ('good', 10), ('driving', 9), ('fun', 9), ('much', 8), ('extremely', 8), ('leather', 8), ('like', 8), ('roomy', 8), ('quality', 7), ('honda', 7), ('long', 7), ('get', 7), ('inside', 6), ('front', 6), ('design', 6), ('performance', 6)]
#
# ===== comfort_toyota_camry_2007 =====
# [('comfortable', 77), ('comfort', 34), ('ride', 25), ('car', 21), ('seats', 19), ('camry', 16), ('quiet', 13), ('great', 12), ('seat', 12), ('interior', 12), ('gas', 9), ('mileage', 9), ('good', 9), ('smooth', 9), ('uncomfortable', 8), ('looks', 8), ('road', 7), ('long', 7), ('room', 7), ('drive', 7), ('driving', 6), ('performance', 6), ('better', 6), ('price', 5), ('trips', 5), ('seating', 5), ('driver', 5), ('like', 5), ('front', 5), ('styling', 4)]
#
# ===== directions_garmin_nuvi_255W_gps =====
# [('directions', 100), ('turn', 17), ('get', 15), ('accurate', 10), ('gps', 9), ('like', 8), ('spoken', 8), ('garmin', 8), ('would', 8), ('time', 8), ('maps', 8), ('voice', 8), ('one', 7), ('easy', 7), ('even', 6), ('screen', 6), ('find', 6), ('give', 6), ('map', 6), ('also', 5), ('features', 5), ('street', 5), ('w', 5), ('driving', 5), ('touch', 5), ('using', 5), ('right', 5), ('location', 5), ('set', 5), ('unit', 5)]
#
# ===== display_garmin_nuvi_255W_gps =====
# [('display', 39), ('speed', 14), ('limit', 10), ('w', 8), ('displayed', 8), ('also', 8), ('map', 8), ('displays', 6), ('screen', 6), ('turn', 6), ('see', 5), ('roads', 4), ('really', 4), ('names', 4), ('night', 3), ('text', 3), ('top', 3), ('feature', 3), ('road', 3), ('right', 3), ('clear', 3), ('easy', 3), ('new', 3), ('left', 3), ('helpful', 3), ('one', 3), ('unit', 3), ('zoom', 3), ('information', 3), ('good', 3)]
#
# ===== eyesight-issues_amazon_kindle =====
# [('eyes', 55), ('easy', 31), ('read', 18), ('screen', 16), ('eye', 15), ('reading', 14), ('kindle', 12), ('strain', 10), ('book', 10), ('font', 10), ('size', 10), ('text', 10), ('page', 9), ('ink', 8), ('e', 7), ('tired', 6), ('like', 6), ('would', 5), ('computer', 5), ('light', 5), ('eyesight', 5), ('using', 5), ('books', 5), ('without', 5), ('make', 5), ('white', 4), ('really', 4), ('one', 4), ('night', 4), ('much', 4)]
#
# ===== features_windows7 =====
# [('features', 62), ('new', 20), ('windows', 20), ('like', 11), ('os', 8), ('vista', 8), ('use', 5), ('xp', 5), ('many', 5), ('much', 4), ('improved', 4), ('desktop', 4), ('experience', 4), ('x', 4), ('things', 4), ('user', 4), ('offers', 4), ('lot', 4), ('still', 4), ('upgrade', 4), ('cool', 4), ('mac', 4), ('programs', 3), ('pc', 3), ('aero', 3), ('environment', 3), ('used', 3), ('time', 3), ('make', 3), ('also', 3)]
#
# ===== fonts_amazon_kindle =====
# [('font', 62), ('size', 33), ('easy', 17), ('change', 16), ('kindle', 11), ('page', 11), ('reading', 10), ('read', 10), ('sizes', 9), ('eyes', 9), ('like', 9), ('text', 8), ('screen', 7), ('books', 7), ('book', 7), ('able', 6), ('make', 5), ('adjustable', 5), ('using', 5), ('tired', 4), ('ability', 4), ('much', 4), ('speech', 4), ('also', 4), ('changing', 3), ('reader', 3), ('fonts', 3), ('ink', 3), ('vision', 3), ('thought', 3)]
#
# ===== food_holiday_inn_london =====
# [('food', 106), ('good', 23), ('hotel', 20), ('fast', 19), ('service', 18), ('great', 15), ('breakfast', 15), ('room', 13), ('restaurants', 12), ('restaurant', 11), ('store', 10), ('around', 9), ('waitrose', 9), ('area', 8), ('tube', 8), ('grocery', 8), ('shops', 8), ('selection', 7), ('well', 7), ('nice', 7), ('many', 7), ('block', 6), ('full', 6), ('one', 6), ('excellent', 6), ('ate', 6), ('also', 6), ('although', 6), ('hot', 6), ('station', 6)]
#
# ===== food_swissotel_chicago =====
# [('food', 52), ('service', 13), ('room', 10), ('hotel', 8), ('good', 7), ('restaurant', 7), ('great', 6), ('night', 6), ('breakfast', 6), ('quality', 5), ('lounge', 4), ('etc', 4), ('lobby', 4), ('also', 4), ('delicious', 3), ('walk', 3), ('blocks', 3), ('expensive', 3), ('palm', 3), ('ate', 3), ('late', 3), ('find', 3), ('well', 3), ('cost', 3), ('grocery', 3), ('south', 3), ('tour', 3), ('store', 3), ('restaurants', 3), ('reasonable', 3)]
#
# ===== free_bestwestern_hotel_sfo =====
# [('free', 125), ('wine', 55), ('coffee', 35), ('morning', 27), ('hotel', 23), ('reception', 20), ('great', 19), ('internet', 19), ('pm', 19), ('biscotti', 18), ('nice', 16), ('hour', 15), ('also', 14), ('evening', 14), ('lobby', 14), ('day', 12), ('every', 12), ('afternoon', 12), ('guests', 11), ('access', 10), ('room', 10), ('get', 10), ('tasting', 9), ('touch', 9), ('good', 8), ('drinks', 8), ('beer', 8), ('available', 7), ('wireless', 7), ('parking', 7)]
#
# ===== gas_mileage_toyota_camry_2007 =====
# [('mileage', 116), ('gas', 65), ('good', 28), ('car', 23), ('great', 22), ('get', 13), ('better', 13), ('camry', 12), ('mpg', 11), ('gets', 8), ('highway', 8), ('poor', 8), ('engine', 7), ('miles', 7), ('comfortable', 6), ('toyota', 6), ('like', 6), ('around', 6), ('ride', 5), ('got', 5), ('power', 5), ('overall', 5), ('cylinder', 5), ('performance', 5), ('city', 4), ('road', 4), ('vehicle', 4), ('excellent', 4), ('still', 4), ('town', 4)]
#
# ===== interior_honda_accord_2008 =====
# [('interior', 95), ('exterior', 18), ('great', 14), ('design', 13), ('car', 12), ('new', 8), ('well', 8), ('comfortable', 8), ('comfort', 7), ('like', 7), ('nice', 7), ('smooth', 7), ('honda', 7), ('love', 6), ('look', 6), ('quality', 6), ('accord', 6), ('leather', 6), ('good', 6), ('dash', 5), ('seat', 5), ('better', 5), ('v', 5), ('seats', 5), ('styling', 5), ('ride', 5), ('room', 5), ('engine', 5), ('roomy', 5), ('body', 4)]
#
# ===== interior_toyota_camry_2007 =====
# [('interior', 110), ('exterior', 20), ('looks', 13), ('car', 12), ('cheap', 11), ('plastic', 11), ('design', 11), ('like', 10), ('love', 9), ('nice', 9), ('roomy', 8), ('good', 8), ('comfortable', 8), ('great', 7), ('quality', 6), ('camry', 6), ('especially', 6), ('styling', 5), ('ride', 5), ('excellent', 5), ('feels', 5), ('seat', 5), ('features', 5), ('poor', 5), ('steering', 5), ('quiet', 5), ('get', 5), ('hard', 5), ('much', 5), ('parts', 4)]
#
# ===== keyboard_netbook_1005ha =====
# [('keyboard', 128), ('screen', 23), ('size', 19), ('good', 16), ('like', 15), ('typing', 14), ('comfortable', 14), ('small', 14), ('use', 12), ('battery', 11), ('easy', 11), ('one', 11), ('type', 11), ('life', 10), ('get', 10), ('used', 10), ('large', 9), ('feel', 9), ('great', 8), ('touch', 8), ('keys', 7), ('full', 7), ('smaller', 7), ('feels', 7), ('really', 7), ('regular', 7), ('would', 6), ('netbooks', 6), ('standard', 6), ('touchpad', 6)]
#
# ===== location_bestwestern_hotel_sfo =====
# [('location', 330), ('great', 129), ('hotel', 111), ('wharf', 106), ('fisherman', 59), ('good', 53), ('perfect', 45), ('cable', 31), ('excellent', 29), ('staff', 28), ('blocks', 27), ('nice', 26), ('inn', 26), ('walk', 26), ('rooms', 25), ('pier', 24), ('tuscan', 24), ('room', 24), ('car', 24), ('clean', 21), ('attractions', 21), ('walking', 21), ('close', 21), ('distance', 19), ('friendly', 19), ('fishermans', 18), ('service', 17), ('best', 16), ('everything', 15), ('within', 15)]
#
# ===== location_holiday_inn_london =====
# [('location', 413), ('great', 149), ('hotel', 142), ('tube', 108), ('good', 85), ('gloucester', 58), ('station', 58), ('excellent', 55), ('road', 48), ('london', 44), ('price', 38), ('walk', 33), ('clean', 31), ('stay', 30), ('kensington', 28), ('rooms', 26), ('around', 26), ('right', 23), ('convenient', 22), ('room', 22), ('nice', 21), ('service', 20), ('near', 20), ('would', 20), ('close', 20), ('block', 19), ('value', 18), ('staff', 18), ('holiday', 18), ('one', 18)]
#
# ===== mileage_honda_accord_2008 =====
# [('mileage', 165), ('gas', 104), ('good', 32), ('great', 28), ('car', 28), ('better', 27), ('mpg', 26), ('highway', 21), ('drive', 15), ('gets', 15), ('city', 14), ('v', 12), ('get', 11), ('accord', 11), ('driving', 10), ('far', 10), ('fuel', 10), ('miles', 9), ('getting', 9), ('honda', 8), ('looks', 7), ('acceleration', 7), ('cylinder', 7), ('smooth', 6), ('ride', 6), ('little', 6), ('poor', 6), ('around', 6), ('disappointed', 6), ('less', 5)]
#
# ===== navigation_amazon_kindle =====
# [('navigation', 35), ('navigate', 20), ('easy', 17), ('kindle', 14), ('easier', 12), ('page', 12), ('way', 9), ('use', 9), ('navigating', 9), ('screen', 8), ('button', 7), ('book', 6), ('k', 5), ('find', 5), ('much', 5), ('used', 4), ('amazon', 4), ('work', 4), ('new', 4), ('e', 4), ('faster', 4), ('pages', 4), ('well', 4), ('easily', 4), ('keyboard', 4), ('touch', 4), ('getting', 3), ('left', 3), ('without', 3), ('cursor', 3)]
#
# ===== parking_bestwestern_hotel_sfo =====
# [('parking', 99), ('valet', 28), ('car', 20), ('hotel', 19), ('night', 15), ('expensive', 10), ('day', 10), ('per', 9), ('pay', 8), ('fee', 7), ('free', 7), ('get', 7), ('room', 7), ('garage', 6), ('rate', 6), ('charge', 6), ('san', 5), ('great', 5), ('lot', 5), ('deal', 5), ('need', 5), ('steep', 5), ('park', 4), ('francisco', 4), ('us', 4), ('street', 4), ('much', 4), ('right', 4), ('really', 4), ('hotels', 4)]
#
# ===== performance_honda_accord_2008 =====
# [('performance', 51), ('car', 16), ('great', 7), ('engine', 7), ('handling', 7), ('honda', 6), ('quality', 6), ('styling', 6), ('good', 5), ('comfort', 5), ('accord', 4), ('gas', 4), ('mileage', 4), ('size', 4), ('reliability', 4), ('lacks', 4), ('v', 4), ('poor', 3), ('overall', 3), ('ride', 3), ('design', 3), ('many', 3), ('looking', 3), ('sports', 3), ('models', 3), ('style', 3), ('happy', 2), ('highway', 2), ('well', 2), ('excellent', 2)]
#
# ===== performance_netbook_1005ha =====
# [('performance', 53), ('battery', 12), ('life', 9), ('great', 7), ('good', 6), ('super', 5), ('mode', 5), ('high', 5), ('computer', 5), ('speed', 4), ('netbooks', 4), ('use', 4), ('gb', 4), ('running', 4), ('software', 3), ('since', 3), ('would', 3), ('hours', 3), ('used', 3), ('laptop', 3), ('much', 3), ('windows', 3), ('wireless', 3), ('stars', 3), ('without', 3), ('using', 3), ('reduction', 3), ('opening', 3), ('eee', 2), ('hybrid', 2)]
#
# ===== price_amazon_kindle =====
# [('price', 74), ('kindle', 31), ('books', 23), ('book', 20), ('would', 14), ('prices', 14), ('priced', 9), ('one', 9), ('find', 9), ('purchase', 9), ('many', 9), ('amazon', 7), ('reading', 7), ('high', 7), ('cost', 7), ('much', 7), ('device', 7), ('cover', 6), ('k', 6), ('still', 5), ('worth', 5), ('paid', 5), ('e', 5), ('reader', 5), ('new', 5), ('even', 5), ('version', 5), ('b', 5), ('included', 4), ('get', 4)]
#
# ===== price_holiday_inn_london =====
# [('price', 143), ('hotel', 50), ('location', 34), ('good', 31), ('room', 29), ('great', 24), ('breakfast', 19), ('would', 19), ('london', 18), ('stay', 16), ('night', 14), ('one', 13), ('get', 13), ('better', 11), ('priceline', 10), ('paid', 9), ('got', 9), ('reasonable', 8), ('beat', 8), ('nice', 7), ('place', 7), ('kensington', 7), ('right', 7), ('hotels', 7), ('included', 6), ('pounds', 6), ('booked', 6), ('much', 6), ('holiday', 6), ('inn', 6)]
#
# ===== quality_toyota_camry_2007 =====
# [('quality', 74), ('toyota', 20), ('car', 15), ('camry', 13), ('build', 11), ('fit', 9), ('poor', 9), ('finish', 7), ('ride', 7), ('interior', 6), ('good', 6), ('great', 5), ('issues', 5), ('reliability', 4), ('design', 4), ('expected', 4), ('excellent', 4), ('sound', 4), ('high', 4), ('new', 4), ('disappointed', 3), ('standards', 3), ('expecting', 3), ('gas', 3), ('however', 3), ('slipping', 3), ('drive', 3), ('terrible', 3), ('far', 3), ('cars', 3)]
#
# ===== rooms_bestwestern_hotel_sfo =====
# [('rooms', 275), ('clean', 67), ('small', 50), ('hotel', 47), ('room', 33), ('nice', 30), ('staff', 28), ('comfortable', 27), ('great', 26), ('location', 23), ('two', 21), ('well', 19), ('decorated', 18), ('courtyard', 16), ('bit', 16), ('us', 15), ('beds', 15), ('size', 15), ('good', 13), ('friendly', 13), ('one', 13), ('street', 12), ('helpful', 12), ('stayed', 11), ('nicely', 10), ('smaller', 10), ('quite', 10), ('bathroom', 9), ('although', 9), ('would', 9)]
#
# ===== rooms_swissotel_chicago =====
# [('rooms', 158), ('clean', 26), ('hotel', 25), ('nice', 22), ('great', 21), ('view', 16), ('spacious', 14), ('room', 14), ('comfortable', 13), ('location', 12), ('would', 12), ('chicago', 11), ('service', 11), ('views', 10), ('large', 10), ('one', 9), ('staff', 9), ('beds', 9), ('floor', 8), ('navy', 8), ('pier', 8), ('swissotel', 7), ('hotels', 7), ('like', 7), ('well', 7), ('good', 7), ('since', 6), ('stay', 6), ('two', 6), ('available', 6)]
#
# ===== room_holiday_inn_london =====
# [('room', 551), ('clean', 121), ('small', 100), ('rooms', 96), ('hotel', 87), ('bathroom', 75), ('bed', 59), ('size', 54), ('good', 50), ('london', 48), ('comfortable', 40), ('floor', 38), ('time', 33), ('great', 33), ('one', 31), ('us', 28), ('would', 28), ('breakfast', 28), ('service', 27), ('staff', 27), ('nice', 26), ('check', 26), ('also', 26), ('although', 24), ('well', 24), ('double', 23), ('night', 23), ('day', 22), ('large', 22), ('got', 21)]
#
# ===== satellite_garmin_nuvi_255W_gps =====
# [('satellites', 33), ('satellite', 32), ('fast', 18), ('time', 12), ('unit', 11), ('quickly', 10), ('turn', 9), ('get', 8), ('gps', 6), ('signals', 6), ('lost', 6), ('minutes', 5), ('signal', 5), ('takes', 5), ('reception', 5), ('connection', 5), ('trip', 4), ('new', 4), ('acquisition', 4), ('faster', 4), ('search', 4), ('seconds', 4), ('acquire', 3), ('take', 3), ('route', 3), ('one', 3), ('road', 3), ('w', 3), ('car', 3), ('much', 3)]
#
# ===== screen_garmin_nuvi_255W_gps =====
# [('screen', 109), ('wide', 13), ('see', 13), ('turn', 13), ('w', 12), ('speed', 11), ('voice', 11), ('touch', 10), ('map', 9), ('also', 9), ('easy', 8), ('limit', 8), ('nuvi', 8), ('one', 8), ('get', 8), ('text', 7), ('garmin', 7), ('directions', 7), ('would', 7), ('volume', 7), ('read', 6), ('top', 6), ('look', 6), ('road', 6), ('gps', 6), ('features', 6), ('need', 6), ('great', 5), ('good', 5), ('even', 5)]
#
# ===== screen_ipod_nano_8gb =====
# [('screen', 59), ('great', 13), ('size', 13), ('video', 11), ('easy', 10), ('ipod', 9), ('camera', 9), ('bigger', 9), ('good', 8), ('new', 8), ('features', 8), ('larger', 7), ('love', 7), ('nano', 7), ('one', 6), ('like', 6), ('nice', 6), ('big', 6), ('small', 6), ('radio', 6), ('last', 6), ('still', 5), ('use', 5), ('wheel', 4), ('battery', 4), ('plus', 4), ('speaker', 4), ('even', 4), ('model', 4), ('much', 4)]
#
# ===== screen_netbook_1005ha =====
# [('screen', 187), ('small', 22), ('keyboard', 20), ('battery', 19), ('life', 17), ('full', 15), ('use', 14), ('size', 14), ('get', 13), ('back', 13), ('resolution', 12), ('one', 12), ('x', 12), ('bright', 11), ('glossy', 11), ('good', 11), ('asus', 10), ('brightness', 10), ('blue', 9), ('screens', 9), ('far', 9), ('great', 9), ('enough', 9), ('much', 8), ('getting', 8), ('laptop', 8), ('netbook', 8), ('used', 7), ('inch', 7), ('better', 7)]
#
# ===== seats_honda_accord_2008 =====
# [('seats', 83), ('comfortable', 17), ('back', 15), ('leather', 14), ('seat', 10), ('uncomfortable', 9), ('front', 8), ('like', 8), ('firm', 7), ('hard', 7), ('quality', 6), ('honda', 6), ('ride', 6), ('heated', 6), ('drive', 5), ('interior', 5), ('accord', 5), ('l', 5), ('memory', 4), ('great', 4), ('road', 4), ('good', 4), ('get', 4), ('design', 4), ('ex', 4), ('supportive', 4), ('vehicle', 4), ('little', 4), ('trip', 3), ('side', 3)]
#
# ===== service_bestwestern_hotel_sfo =====
# [('service', 142), ('hotel', 37), ('great', 27), ('good', 23), ('room', 17), ('staff', 16), ('location', 16), ('food', 14), ('friendly', 11), ('rooms', 11), ('concierge', 10), ('restaurant', 10), ('clean', 10), ('excellent', 10), ('cafe', 10), ('us', 9), ('helpful', 9), ('would', 9), ('nice', 9), ('breakfast', 9), ('time', 8), ('valet', 8), ('day', 7), ('front', 6), ('desk', 6), ('tuscan', 6), ('comfortable', 6), ('like', 6), ('maid', 6), ('quot', 6)]
#
# ===== service_holiday_inn_london =====
# [('service', 166), ('room', 60), ('hotel', 34), ('good', 32), ('great', 21), ('location', 20), ('staff', 15), ('food', 15), ('stay', 12), ('excellent', 12), ('poor', 12), ('customer', 11), ('breakfast', 11), ('rooms', 11), ('concierge', 11), ('quality', 11), ('clean', 9), ('london', 9), ('one', 9), ('floor', 9), ('reception', 8), ('better', 8), ('day', 8), ('would', 8), ('well', 8), ('nice', 8), ('friendly', 7), ('holiday', 7), ('also', 7), ('services', 7)]
#
# ===== service_swissotel_hotel_chicago =====
# [('service', 188), ('room', 72), ('hotel', 44), ('great', 23), ('staff', 19), ('rooms', 15), ('good', 14), ('services', 13), ('stay', 13), ('location', 13), ('excellent', 12), ('nice', 12), ('customer', 12), ('view', 11), ('top', 11), ('food', 11), ('breakfast', 11), ('swissotel', 11), ('us', 11), ('night', 10), ('concierge', 10), ('day', 10), ('desk', 10), ('one', 10), ('front', 10), ('chicago', 10), ('would', 9), ('internet', 9), ('friendly', 9), ('charge', 9)]
#
# ===== size_asus_netbook_1005ha =====
# [('size', 73), ('full', 26), ('keyboard', 23), ('screen', 20), ('small', 19), ('laptop', 18), ('sized', 14), ('battery', 11), ('life', 9), ('great', 9), ('right', 8), ('even', 8), ('use', 8), ('used', 8), ('one', 8), ('smaller', 7), ('take', 7), ('get', 7), ('enough', 6), ('standard', 6), ('netbook', 6), ('large', 6), ('like', 5), ('weight', 5), ('using', 5), ('things', 4), ('feel', 4), ('keys', 4), ('big', 4), ('perfect', 4)]
#
# ===== sound_ipod_nano_8gb =====
# [('sound', 99), ('quality', 46), ('great', 40), ('easy', 22), ('use', 21), ('good', 18), ('video', 13), ('ipod', 11), ('love', 10), ('headphones', 9), ('music', 7), ('nano', 7), ('headphone', 6), ('picture', 6), ('really', 6), ('speaker', 6), ('radio', 6), ('jack', 5), ('excellent', 5), ('awesome', 5), ('camera', 5), ('also', 5), ('features', 5), ('storage', 5), ('battery', 5), ('compact', 5), ('clear', 4), ('sounds', 4), ('would', 4), ('improved', 4)]
#
# ===== speed_garmin_nuvi_255W_gps =====
# [('speed', 89), ('limit', 47), ('road', 14), ('time', 10), ('screen', 9), ('shows', 9), ('current', 8), ('limits', 8), ('posted', 7), ('tells', 7), ('major', 7), ('driving', 7), ('feature', 6), ('w', 6), ('display', 6), ('route', 6), ('turn', 6), ('roads', 6), ('see', 5), ('also', 5), ('arrival', 5), ('highways', 5), ('along', 5), ('way', 5), ('actual', 5), ('sign', 5), ('speedometer', 4), ('really', 4), ('new', 4), ('helpful', 4)]
#
# ===== speed_windows7 =====
# [('faster', 77), ('fast', 37), ('vista', 29), ('windows', 21), ('xp', 18), ('much', 18), ('win', 11), ('system', 11), ('slower', 9), ('install', 9), ('slow', 9), ('computer', 8), ('run', 8), ('bit', 8), ('runs', 8), ('start', 8), ('stable', 7), ('use', 7), ('also', 7), ('time', 7), ('os', 7), ('boot', 7), ('like', 7), ('upgrade', 7), ('boots', 6), ('files', 6), ('performance', 6), ('hardware', 6), ('programs', 6), ('seems', 6)]
#
# ===== staff_bestwestern_hotel_sfo =====
# [('staff', 318), ('friendly', 112), ('helpful', 111), ('hotel', 63), ('great', 42), ('desk', 40), ('front', 33), ('room', 32), ('clean', 32), ('rooms', 30), ('us', 28), ('location', 28), ('concierge', 24), ('nice', 22), ('wine', 19), ('check', 19), ('good', 17), ('comfortable', 16), ('pleasant', 16), ('found', 15), ('extremely', 15), ('really', 14), ('service', 13), ('excellent', 13), ('evening', 13), ('morning', 12), ('one', 12), ('reception', 12), ('day', 12), ('quot', 11)]
#
# ===== staff_swissotel_chicago =====
# [('staff', 204), ('friendly', 45), ('hotel', 41), ('helpful', 40), ('room', 28), ('desk', 27), ('great', 26), ('front', 21), ('nice', 20), ('service', 17), ('us', 15), ('courteous', 12), ('professional', 12), ('check', 12), ('location', 10), ('like', 9), ('concierge', 9), ('efficient', 9), ('swissotel', 8), ('rooms', 8), ('extremely', 8), ('need', 8), ('quot', 8), ('way', 7), ('everything', 7), ('good', 7), ('clean', 7), ('rude', 7), ('every', 7), ('always', 7)]
#
# ===== transmission_toyota_camry_2007 =====
# [('transmission', 154), ('car', 17), ('problems', 16), ('shifts', 16), ('engine', 16), ('power', 12), ('smooth', 12), ('speed', 11), ('problem', 11), ('hesitation', 9), ('gears', 9), ('driving', 8), ('gas', 8), ('toyota', 8), ('camry', 8), ('new', 8), ('cyl', 8), ('rattles', 7), ('issues', 7), ('shift', 7), ('shifting', 7), ('auto', 7), ('much', 6), ('manual', 6), ('terrible', 6), ('control', 6), ('everyone', 5), ('gear', 5), ('get', 5), ('issue', 5)]
#
# ===== updates_garmin_nuvi_255W_gps =====
# [('update', 42), ('map', 26), ('garmin', 14), ('maps', 14), ('updates', 13), ('updated', 11), ('unit', 10), ('get', 9), ('time', 7), ('software', 7), ('free', 7), ('gps', 6), ('download', 6), ('traffic', 5), ('site', 5), ('latest', 5), ('also', 5), ('another', 4), ('cable', 4), ('first', 4), ('internet', 4), ('tts', 4), ('one', 4), ('screen', 3), ('told', 3), ('shows', 3), ('turn', 3), ('days', 3), ('gb', 3), ('long', 3)]
#
# ===== video_ipod_nano_8gb =====
# [('video', 191), ('camera', 83), ('music', 39), ('great', 37), ('ipod', 36), ('videos', 35), ('use', 32), ('quality', 26), ('radio', 24), ('nano', 23), ('easy', 20), ('feature', 18), ('good', 17), ('love', 14), ('sound', 14), ('features', 13), ('nice', 13), ('screen', 12), ('small', 11), ('new', 11), ('size', 11), ('take', 11), ('pictures', 11), ('recording', 10), ('awesome', 10), ('way', 9), ('like', 9), ('fun', 9), ('also', 9), ('itunes', 8)]
#
# ===== voice_garmin_nuvi_255W_gps =====
# [('voice', 74), ('voices', 23), ('clear', 17), ('like', 15), ('turn', 14), ('directions', 12), ('screen', 10), ('robotic', 8), ('even', 8), ('english', 8), ('also', 7), ('w', 7), ('garmin', 7), ('sound', 7), ('much', 7), ('one', 7), ('text', 6), ('get', 6), ('easy', 6), ('make', 6), ('time', 6), ('prompts', 5), ('female', 5), ('really', 5), ('unit', 5), ('better', 5), ('gps', 5), ('understand', 5), ('street', 5), ('names', 5)]

# %%
document_df['opinion_text'] = document_df['opinion_text'].apply(
    lambda x: ' '.join(x)
)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# 1. CountVectorizer
count_vect = CountVectorizer(
    ngram_range=(1, 2),
    min_df=0.05,
    max_df=0.85
)

X_count = count_vect.fit_transform(
    document_df['opinion_text']
)

# %%
from sklearn.cluster import KMeans


# 5개 집합으로 군집화 수행. 예제를 위해 동일한 클러스터링 결과 도출용 random_state=0
km_cluster = KMeans(n_clusters=4, max_iter=10000, random_state=0)
km_cluster.fit(X_count)
cluster_label = km_cluster.labels_
cluster_centers = km_cluster.cluster_centers_

document_df['cluster_label'] = cluster_label

# %%
document_df[document_df['cluster_label']==4][['filename','opinion_text','cluster_label']].sort_values(by='filename')
# Out:
# Empty DataFrame
# Columns: [filename, opinion_text, cluster_label]
# Index: []

# %%
document_df[document_df['cluster_label']==3][['filename','opinion_text','cluster_label']].sort_values(by='filename')
# Out:
#                        filename  \
# 45  staff_bestwestern_hotel_sfo
# 46      staff_swissotel_chicago
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    opinion_text  \
# 45  staff friendly helpful staff morning seemed need another cup coffee excited see us perfect hotel perfect location perfect staff front desk staff eager help smile make happy staff friendly went one quot happy hours quot glass wine either baseball game two tours took busy time front desk concierge staff helpful question staff helpful knowledgable room clean comfortable staff friendly helpful staff helpful got two great suggestions dinner water booked shuttle back airport way cheaper taxi service good friendly staff loved free wine reception night staff desk rarely welcomed back day sightseeing etc found concierge front desk staff helpful housekeepers quite good check check efficient howeve...
# 46  staff swissotel particularly nice time waited counter staff several minutes waved desk upon turn hello anything apology waiting line staff members courteous go extra mile meeting needs stay staff great put us th floor view lake staff friendly knowledgeable town go way helpful whole stay felt like staff went way make sure best visit possible great rooms staff location extras overpriced hotel staff nice moment drove positive great room comfortable bedvery friendly staff help way caninternet staff professional courteous friendly great location great staff great everything staff terrific room business aspects event staff hotel helpful nice checkin swift friendly staff explained everything go...
#
#     cluster_label
# 45              3
# 46              3

# %%
# 군집별 top n 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명들을 반환함.
def get_cluster_details(cluster_model, cluster_data, feature_names, clusters_num, top_n_features=10):
    cluster_details = {}
   
    # cluster_centers array 의 값이 큰 순으로 정렬된 index 값을 반환
    # 군집 중심점(centroid)별 할당된 word 피처들의 거리값이 큰 순으로 값을 구하기 위함.  
    centroid_feature_ordered_ind = cluster_model.cluster_centers_.argsort()[:,::-1]
   
    #개별 군집별로 iteration하면서 핵심단어, 그 단어의 중심 위치 상대값, 대상 파일명 입력
    for cluster_num in range(clusters_num):
        # 개별 군집별 정보를 담을 데이터 초기화.
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster'] = cluster_num
       
        # cluster_centers_.argsort()[:,::-1] 로 구한 index 를 이용하여 top n 피처 단어를 구함.
        top_feature_indexes = centroid_feature_ordered_ind[cluster_num, :top_n_features]
        top_features = [ feature_names[ind] for ind in top_feature_indexes ]
       
        # top_feature_indexes를 이용해 해당 피처 단어의 중심 위치 상댓값 구함
        top_feature_values = cluster_model.cluster_centers_[cluster_num, top_feature_indexes].tolist()
       
        # cluster_details 딕셔너리 객체에 개별 군집별 핵심 단어와 중심위치 상대값, 그리고 해당 파일명 입력
        cluster_details[cluster_num]['top_features'] = top_features
        cluster_details[cluster_num]['top_features_value'] = top_feature_values
        filenames = cluster_data[cluster_data['cluster_label'] == cluster_num]['filename']
        filenames = filenames.values.tolist()
        cluster_details[cluster_num]['filenames'] = filenames
       
    return cluster_details

# %%
def print_cluster_details(cluster_details):
    for cluster_num, cluster_detail in cluster_details.items():
        print('####### Cluster {0}'.format(cluster_num))
        print('Top features:', cluster_detail['top_features'])
        print('Reviews 파일명 :',cluster_detail['filenames'][:7])
        print('==================================================')

# %%
feature_names = count_vect.get_feature_names_out()


cluster_details = get_cluster_details(cluster_model=km_cluster, cluster_data=document_df,\
                                  feature_names=feature_names, clusters_num=4, top_n_features=10 )
print_cluster_details(cluster_details)
# Out:
# ####### Cluster 0
# Top features: ['battery', 'service', 'screen', 'rooms', 'room', 'comfortable', 'hotel', 'mileage', 'life', 'price']
# Reviews 파일명 : ['accuracy_garmin_nuvi_255W_gps', 'bathroom_bestwestern_hotel_sfo', 'battery-life_amazon_kindle', 'battery-life_ipod_nano_8gb', 'battery-life_netbook_1005ha', 'buttons_amazon_kindle', 'comfort_honda_accord_2008']
# ==================================================
# ####### Cluster 1
# Top features: ['room', 'clean', 'small', 'rooms', 'hotel', 'bathroom', 'bed', 'size', 'london', 'room clean']
# Reviews 파일명 : ['room_holiday_inn_london']
# ==================================================
# ####### Cluster 2
# Top features: ['location', 'hotel', 'great location', 'tube', 'wharf', 'excellent', 'location great', 'good location', 'perfect', 'walk']
# Reviews 파일명 : ['location_bestwestern_hotel_sfo', 'location_holiday_inn_london']
# ==================================================
# ####### Cluster 3
# Top features: ['staff', 'friendly', 'helpful', 'hotel', 'staff friendly', 'desk', 'room', 'front', 'front desk', 'us']
# Reviews 파일명 : ['staff_bestwestern_hotel_sfo', 'staff_swissotel_chicago']
# ==================================================

# %%
from sklearn.metrics import silhouette_score

count_score = silhouette_score(
    X_count,
    cluster_label
)


print("CountVectorizer :", count_score)
# Out:
# CountVectorizer : 0.44099534514355626

# %%
document_df.value_counts('cluster_label')
# Out:
# cluster_label
# 0    46
# 2     2
# 3     2
# 1     1
# Name: count, dtype: int64

# %%
from sklearn.decomposition import PCA

X_dense = X_count.toarray()

pca_2d = PCA(
    n_components=2,
    random_state=42
)

X_2d = pca_2d.fit_transform(X_dense)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 6))

plt.scatter(
    X_2d[:, 0],
    X_2d[:, 1],
    c=cluster_label
)

plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title('KMeans Clustering')

plt.show()
