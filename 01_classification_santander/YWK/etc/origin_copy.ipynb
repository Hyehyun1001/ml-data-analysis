# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import matplotlib
matplotlib.use("Agg") #Needed to save figures
# ▼▼▼ [수정 전 - 구버전, 주석 처리됨] ▼▼▼
# from sklearn import cross_validation  # 최신 sklearn에서 제거된 모듈
from sklearn.model_selection import train_test_split
import xgboost as xgb
from sklearn.metrics import roc_auc_score

training = pd.read_csv("../data/santander-customer-satisfaction/train.csv", index_col=0)
test = pd.read_csv("../data/santander-customer-satisfaction/test.csv", index_col=0)

print(training.shape)
print(test.shape)

# Replace -999999 in var3 column with most common value 2 
# See https://www.kaggle.com/cast42/santander-customer-satisfaction/debugging-var3-999999
# for details
training = training.replace(-999999,2)


# Replace 9999999999 with NaN
# See https://www.kaggle.com/c/santander-customer-satisfaction/forums/t/19291/data-dictionary/111360#post111360
# training = training.replace(9999999999, np.nan)
# training.dropna(inplace=True)
# Leads to validation_0-auc:0.839577

X = training.iloc[:,:-1]
y = training.TARGET

# Add zeros per row as extra feature
X['n0'] = (X == 0).sum(axis=1) # 0의 개수를 세어 n0라는 새로운 feature를 추가/0의 개수가 많은 고객은 
# # Add log of var38
# X['logvar38'] = X['var38'].map(np.log1p)
# # Encode var36 as category
# X['var36'] = X['var36'].astype('category')
# X = pd.get_dummies(X)

# Add PCA components as features
from sklearn.preprocessing import normalize
from sklearn.decomposition import PCA

X_normalized = normalize(X, axis=0)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_normalized)
X['PCA1'] = X_pca[:,0]
X['PCA2'] = X_pca[:,1]

from sklearn.feature_selection import SelectPercentile
from sklearn.feature_selection import f_classif,chi2
from sklearn.preprocessing import Binarizer, scale

p = 86 # 308 features validation_1-auc:0.848039
p = 80 # 284 features validation_1-auc:0.848414
p = 77 # 267 features validation_1-auc:0.848000
p = 75 # 261 features validation_1-auc:0.848642
# p = 73 # 257 features validation_1-auc:0.848338
# p = 70 # 259 features validation_1-auc:0.848588
# p = 69 # 238 features validation_1-auc:0.848547
# p = 67 # 247 features validation_1-auc:0.847925
# p = 65 # 240 features validation_1-auc:0.846769
# p = 60 # 222 features validation_1-auc:0.848581

X_bin = Binarizer().fit_transform(scale(X))
selectChi2 = SelectPercentile(chi2, percentile=p).fit(X_bin, y)
selectF_classif = SelectPercentile(f_classif, percentile=p).fit(X, y)

chi2_selected = selectChi2.get_support()
chi2_selected_features = [ f for i,f in enumerate(X.columns) if chi2_selected[i]]
print('Chi2 selected {} features {}.'.format(chi2_selected.sum(),
   chi2_selected_features))
f_classif_selected = selectF_classif.get_support()
f_classif_selected_features = [ f for i,f in enumerate(X.columns) if f_classif_selected[i]]
print('F_classif selected {} features {}.'.format(f_classif_selected.sum(),
   f_classif_selected_features))
selected = chi2_selected & f_classif_selected
print('Chi2 & F_classif selected {} features'.format(selected.sum()))
features = [ f for f,s in zip(X.columns, selected) if s]
print (features)

X_sel = X[features]

# ▼▼▼ [수정 전 - 구버전, 주석 처리됨] ▼▼▼
# X_train, X_test, y_train, y_test = \
#   cross_validation.train_test_split(X_sel, y, random_state=1301, stratify=y, test_size=0.4)  # cross_validation 모듈 제거됨
X_train, X_test, y_train, y_test = \
  train_test_split(X_sel, y, random_state=1301, stratify=y, test_size=0.4)

# xgboost parameter tuning with p = 75
# recipe: https://www.kaggle.com/c/bnp-paribas-cardif-claims-management/forums/t/19083/best-practices-for-parameter-tuning-on-models/108783#post108783

ratio = float(np.sum(y == 1)) / np.sum(y==0)
# Initial parameters for the parameter exploration
# clf = xgb.XGBClassifier(missing=9999999999,
#                 max_depth = 10,
#                 n_estimators=1000,
#                 learning_rate=0.1, 
#                 nthread=4,
#                 subsample=1.0,
#                 colsample_bytree=0.5,
#                 min_child_weight = 5,
#                 scale_pos_weight = ratio,
#                 seed=4242)

# gives : validation_1-auc:0.845644
# max_depth=8 -> validation_1-auc:0.846341
# max_depth=6 -> validation_1-auc:0.845738
# max_depth=7 -> validation_1-auc:0.846504
# subsample=0.8 -> validation_1-auc:0.844440
# subsample=0.9 -> validation_1-auc:0.844746
# subsample=1.0,  min_child_weight=8 -> validation_1-auc:0.843393
# min_child_weight=3 -> validation_1-auc:0.848534
# min_child_weight=1 -> validation_1-auc:0.846311
# min_child_weight=4 -> validation_1-auc:0.847994
# min_child_weight=2 -> validation_1-auc:0.847934
# min_child_weight=3, colsample_bytree=0.3 -> validation_1-auc:0.847498
# colsample_bytree=0.7 -> validation_1-auc:0.846984
# colsample_bytree=0.6 -> validation_1-auc:0.847856
# colsample_bytree=0.5, learning_rate=0.05 -> validation_1-auc:0.847347
# max_depth=8 -> validation_1-auc:0.847352
# learning_rate = 0.07 -> validation_1-auc:0.847432
# learning_rate = 0.2 -> validation_1-auc:0.846444
# learning_rate = 0.15 -> validation_1-auc:0.846889
# learning_rate = 0.09 -> validation_1-auc:0.846680
# learning_rate = 0.1 -> validation_1-auc:0.847432
# max_depth=7 -> validation_1-auc:0.848534
# learning_rate = 0.05 -> validation_1-auc:0.847347
# 

# ▼▼▼ [수정 전 - 구버전, 주석 처리됨] ▼▼▼
# clf = xgb.XGBClassifier(missing=9999999999,
#                 max_depth = 5,
#                 n_estimators=1000,
#                 learning_rate=0.1, 
#                 nthread=4,
#                 subsample=1.0,
#                 colsample_bytree=0.5,
#                 min_child_weight = 3,
#                 scale_pos_weight = ratio,
#                 reg_alpha=0.03,
#                 seed=1301)
#
clf = xgb.XGBClassifier(missing=9999999999,
                max_depth = 5,
                n_estimators=1000,
                learning_rate=0.1, 
                nthread=4,
                subsample=1.0,
                colsample_bytree=0.5,
                min_child_weight = 3,
                scale_pos_weight = ratio,
                reg_alpha=0.03,
                seed=1301,
                early_stopping_rounds=50,  # xgboost>=2.0: fit()이 아닌 생성자에서 설정
                eval_metric="auc")

# ▼▼▼ [수정 전 - 구버전, 주석 처리됨] ▼▼▼
# clf.fit(X_train, y_train, early_stopping_rounds=50, eval_metric="auc",
#         eval_set=[(X_train, y_train), (X_test, y_test)])
#
clf.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)])

# ▼▼▼ [수정 전 - 구버전, 주석 처리됨] ▼▼▼
# print('Overall AUC:', roc_auc_score(y, clf.predict_proba(X_sel, ntree_limit=clf.best_iteration)[:,1]))  # ntree_limit은 xgboost 2.0에서 제거됨
print('Overall AUC:', roc_auc_score(y, clf.predict_proba(X_sel, iteration_range=(0, clf.best_iteration + 1))[:,1]))

test['n0'] = (test == 0).sum(axis=1)
# test['logvar38'] = test['var38'].map(np.log1p)
# # Encode var36 as category
# test['var36'] = test['var36'].astype('category')
# test = pd.get_dummies(test)
test_normalized = normalize(test, axis=0)
pca = PCA(n_components=2)
test_pca = pca.fit_transform(test_normalized)
test['PCA1'] = test_pca[:,0]
test['PCA2'] = test_pca[:,1]
sel_test = test[features]    
# ▼▼▼ [수정 전 - 구버전, 주석 처리됨] ▼▼▼
# y_pred = clf.predict_proba(sel_test, ntree_limit=clf.best_iteration)  # ntree_limit은 xgboost 2.0에서 제거됨
y_pred = clf.predict_proba(sel_test, iteration_range=(0, clf.best_iteration + 1))

submission = pd.DataFrame({"ID":test.index, "TARGET":y_pred[:,1]})
submission.to_csv("submission.csv", index=False)

mapFeat = dict(zip(["f"+str(i) for i in range(len(features))],features))
# ▼▼▼ [수정 전 - 구버전, 주석 처리됨] ▼▼▼
# ts = pd.Series(clf.booster().get_fscore())  # booster()는 존재하지 않음, get_booster() 사용
ts = pd.Series(clf.get_booster().get_fscore())
#ts.index = ts.reset_index()['index'].map(mapFeat)
ts.sort_values()[-15:].plot(kind="barh", title=("features importance"))

featp = ts.sort_values()[-15:].plot(kind='barh', x='feature', y='fscore', legend=False, figsize=(6, 10))
plt.title('XGBoost Feature Importance')
fig_featp = featp.get_figure()
fig_featp.savefig('feature_importance_xgb.png', bbox_inches='tight', pad_inches=1)

# 22.2s
# Out:
# (76020, 370)
# (75818, 369)
# C:\Users\mega\AppData\Local\Temp\ipykernel_16496\587724534.py:34: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['n0'] = (X == 0).sum(axis=1)
# C:\Users\mega\AppData\Local\Temp\ipykernel_16496\587724534.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['PCA1'] = X_pca[:,0]
# C:\Users\mega\AppData\Local\Temp\ipykernel_16496\587724534.py:49: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X['PCA2'] = X_pca[:,1]
# c:\Users\mega\anaconda3\envs\ml_dev\Lib\site-packages\sklearn\preprocessing\_data.py:275: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# c:\Users\mega\anaconda3\envs\ml_dev\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:110: UserWarning: Features [ 21  22  56  57  58  59  80  84  85 131 132 133 134 155 161 162 179 180
#  189 192 220 222 234 238 244 248 261 262 303 307 315 319 327 349] are constant.
#   warnings.warn("Features %s are constant." % constant_features_idx, UserWarning)
# c:\Users\mega\anaconda3\envs\ml_dev\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:111: RuntimeWarning: invalid value encountered in divide
#   f = msb / msw
# Chi2 selected 279 features ['var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_comer_ult3', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'imp_sal_var16_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var40_ult3', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var35', 'num_var37_med_ult2', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var1', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var17', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_hace3', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_emit_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_in_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_hace3', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3', 'num_meses_var13_largo_ult3', 'nu ...
# F_classif selected 279 features ['var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var6', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13_medio_0', 'num_var13_medio', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var18_0', 'num_var18', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var29', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var34_0', 'num_var34', 'num_var35', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_amort_var18_1y3', 'delta_imp_amort_var34_1y3', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_reemb_var17_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var7_recib_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var1 ...
# Chi2 & F_classif selected 263 features
# ['var3', 'var15', 'imp_op_var39_comer_ult1', 'imp_op_var39_comer_ult3', 'imp_op_var40_comer_ult1', 'imp_op_var40_efect_ult1', 'imp_op_var40_efect_ult3', 'imp_op_var40_ult1', 'imp_op_var41_comer_ult1', 'imp_op_var41_comer_ult3', 'imp_op_var41_efect_ult1', 'imp_op_var41_efect_ult3', 'imp_op_var41_ult1', 'imp_op_var39_efect_ult1', 'imp_op_var39_efect_ult3', 'imp_op_var39_ult1', 'ind_var1_0', 'ind_var1', 'ind_var5_0', 'ind_var5', 'ind_var6_0', 'ind_var8_0', 'ind_var8', 'ind_var12_0', 'ind_var12', 'ind_var13_0', 'ind_var13_corto_0', 'ind_var13_corto', 'ind_var13_largo_0', 'ind_var13_largo', 'ind_var13', 'ind_var14_0', 'ind_var14', 'ind_var17_0', 'ind_var17', 'ind_var19', 'ind_var20_0', 'ind_var20', 'ind_var24_0', 'ind_var24', 'ind_var25_cte', 'ind_var26_0', 'ind_var26_cte', 'ind_var26', 'ind_var25_0', 'ind_var25', 'ind_var29_0', 'ind_var30', 'ind_var31_0', 'ind_var31', 'ind_var32_cte', 'ind_var33_0', 'ind_var33', 'ind_var37_cte', 'ind_var37_0', 'ind_var37', 'ind_var39_0', 'ind_var40_0', 'ind_var40', 'ind_var41_0', 'ind_var39', 'ind_var44_0', 'ind_var44', 'num_var1_0', 'num_var1', 'num_var4', 'num_var5_0', 'num_var5', 'num_var6_0', 'num_var8_0', 'num_var8', 'num_var12_0', 'num_var12', 'num_var13_0', 'num_var13_corto_0', 'num_var13_corto', 'num_var13_largo_0', 'num_var13_largo', 'num_var13', 'num_var14_0', 'num_var14', 'num_var17_0', 'num_var17', 'num_var20_0', 'num_var20', 'num_var24_0', 'num_var24', 'num_var26_0', 'num_var26', 'num_var25_0', 'num_var25', 'num_op_var40_hace2', 'num_op_var40_hace3', 'num_op_var40_ult1', 'num_op_var41_hace2', 'num_op_var41_hace3', 'num_op_var41_ult1', 'num_op_var41_ult3', 'num_op_var39_hace2', 'num_op_var39_hace3', 'num_op_var39_ult1', 'num_op_var39_ult3', 'num_var29_0', 'num_var30_0', 'num_var30', 'num_var31_0', 'num_var31', 'num_var33_0', 'num_var33', 'num_var35', 'num_var37_0', 'num_var37', 'num_var39_0', 'num_var40_0', 'num_var40', 'num_var41_0', 'num_var39', 'num_var42_0', 'num_var42', 'num_var44_0', 'num_var44', 'saldo_var5', 'saldo_var8', 'saldo_var12', 'saldo_var13_corto', 'saldo_var13_largo', 'saldo_var13', 'saldo_var14', 'saldo_var20', 'saldo_var24', 'saldo_var26', 'saldo_var25', 'saldo_var30', 'saldo_var31', 'saldo_var33', 'saldo_var37', 'saldo_var40', 'saldo_var42', 'saldo_var44', 'var36', 'delta_imp_aport_var13_1y3', 'delta_imp_aport_var17_1y3', 'delta_imp_compra_var44_1y3', 'delta_imp_reemb_var13_1y3', 'delta_imp_trasp_var17_in_1y3', 'delta_imp_trasp_var17_out_1y3', 'delta_imp_trasp_var33_in_1y3', 'delta_imp_venta_var44_1y3', 'delta_num_aport_var13_1y3', 'delta_num_aport_var17_1y3', 'delta_num_compra_var44_1y3', 'delta_num_reemb_var13_1y3', 'delta_num_trasp_var17_in_1y3', 'delta_num_trasp_var17_out_1y3', 'delta_num_trasp_var33_in_1y3', 'delta_num_venta_var44_1y3', 'imp_aport_var13_hace3', 'imp_aport_var13_ult1', 'imp_aport_var17_ult1', 'imp_aport_var33_hace3', 'imp_aport_var33_ult1', 'imp_var7_recib_ult1', 'imp_compra_var44_hace3', 'imp_compra_var44_ult1', 'imp_reemb_var13_ult1', 'imp_var43_emit_ult1', 'imp_trans_var37_ult1', 'imp_trasp_var17_out_ult1', 'imp_trasp_var33_in_hace3', 'imp_trasp_var33_in_ult1', 'imp_venta_var44_ult1', 'ind_var7_emit_ult1', 'ind_var10_ult1', 'ind_var10cte_ult1', 'ind_var9_cte_ult1', 'ind_var9_ult1', 'ind_var43_emit_ult1', 'ind_var43_recib_ult1', 'var21', 'num_aport_var13_hace3', 'num_aport_var13_ult1', 'num_aport_var17_hace3', 'num_aport_var17_ult1', 'num_aport_var33_hace3', 'num_aport_var33_ult1', 'num_var7_emit_ult1', 'num_compra_var44_hace3', 'num_compra_var44_ult1', 'num_ent_var16_ult1', 'num_var22_hace2', 'num_var22_hace3', 'num_var22_ult1', 'num_var22_ult3', 'num_med_var45_ult3', 'num_meses_var5_ult3', 'num_meses_var8_ult3', 'num_meses_var12_ult3', 'num_meses_var13_corto_ult3', 'num_meses_var13_largo_ult3', 'num_meses_var17_ult3', 'num_meses_var29_ult3', 'num_meses_var33_ult3', 'num_meses_var39_vig_ult3', 'num_meses_var44_ult3', 'num_op_var39_comer_ult1', 'num_op_var40_comer_ult1', 'num_op_var40_comer_ult3', 'num_op_var40_efect_ult1', 'num_op_var40_efec ...
# [0]	validation_0-auc:0.50000	validation_1-auc:0.50000
# [1]	validation_0-auc:0.50000	validation_1-auc:0.50000
# [2]	validation_0-auc:0.50000	validation_1-auc:0.50000
# [3]	validation_0-auc:0.50000	validation_1-auc:0.50000
# [4]	validation_0-auc:0.50000	validation_1-auc:0.50000
# [5]	validation_0-auc:0.50000	validation_1-auc:0.50000
# [6]	validation_0-auc:0.71237	validation_1-auc:0.71704
# [7]	validation_0-auc:0.71220	validation_1-auc:0.71694
# [8]	validation_0-auc:0.71220	validation_1-auc:0.71694
# [9]	validation_0-auc:0.71421	validation_1-auc:0.71826
# [10]	validation_0-auc:0.71421	validation_1-auc:0.71826
# [11]	validation_0-auc:0.71421	validation_1-auc:0.71826
# [12]	validation_0-auc:0.71639	validation_1-auc:0.72015
# [13]	validation_0-auc:0.71739	validation_1-auc:0.72066
# [14]	validation_0-auc:0.71740	validation_1-auc:0.72056
# [15]	validation_0-auc:0.71737	validation_1-auc:0.72059
# [16]	validation_0-auc:0.71747	validation_1-auc:0.72121
# [17]	validation_0-auc:0.71752	validation_1-auc:0.72136
# [18]	validation_0-auc:0.71866	validation_1-auc:0.72309
# [19]	validation_0-auc:0.71898	validation_1-auc:0.72319
# [20]	validation_0-auc:0.72778	validation_1-auc:0.73091
# [21]	validation_0-auc:0.73085	validation_1-auc:0.73259
# [22]	validation_0-auc:0.73334	validation_1-auc:0.73487
# [23]	validation_0-auc:0.73610	validation_1-auc:0.73719
# [24]	validation_0-auc:0.77480	validation_1-auc:0.78034
# [25]	validation_0-auc:0.77592	validation_1-auc:0.78088
# [26]	validation_0-auc:0.77646	validation_1-auc:0.78091
# [27]	validation_0-auc:0.79176	validation_1-auc:0.79329
# [28]	validation_0-auc:0.79332	validation_1-auc:0.79544
# [29]	validation_0-auc:0.79390	validation_1-auc:0.79576
# [30]	validation_0-auc:0.79922	validation_1-auc:0.80005
# [31]	validation_0-auc:0.79980	validation_1-auc:0.80095
# [32]	validation_0-auc:0.79873	validation_1-auc:0.79979
# [33]	validation_0-auc:0.79848	validation_1-auc:0.79947
# [34]	validation_0-auc:0.79936	validation_1-auc:0.79957
# [35]	validation_0-auc:0.80346	validation_1-auc:0.80189
# [36]	validation_0-auc:0.80241	validation_1-auc:0.80097
# [37]	validation_0-auc:0.80144	validation_1-auc:0.80034
# [38]	validation_0-auc:0.80226	validation_1-auc:0.80225
# [39]	validation_0-auc:0.80168	validation_1-auc:0.80147
# [40]	validation_0-auc:0.80114	validation_1-auc:0.80123
# [41]	validation_0-auc:0.80896	validation_1-auc:0.80823
# [42]	validation_0-auc:0.81822	validation_1-auc:0.81742
# [43]	validation_0-auc:0.81848	validation_1-auc:0.81818
# [44]	validation_0-auc:0.82070	validation_1-auc:0.82109
# [45]	validation_0-auc:0.82560	validation_1-auc:0.82528
# [46]	validation_0-auc:0.82461	validation_1-auc:0.82476
# [47]	validation_0-auc:0.82458	validation_1-auc:0.82348
# [48]	validation_0-auc:0.82419	validation_1-auc:0.82317
# [49]	validation_0-auc:0.82548	validation_1-auc:0.82351
# [50]	validation_0-auc:0.82937	validation_1-auc:0.82783
# [51]	validation_0-auc:0.82908	validation_1-auc:0.82720
# [52]	validation_0-auc:0.82842	validation_1-auc:0.82646
# [53]	validation_0-auc:0.82805	validation_1-auc:0.82551
# [54]	validation_0-auc:0.83089	validation_1-auc:0.82817
# [55]	validation_0-auc:0.83214	validation_1-auc:0.82969
# [56]	validation_0-auc:0.83203	validation_1-auc:0.82977
# [57]	validation_0-auc:0.83252	validation_1-auc:0.82964
# [58]	validation_0-auc:0.83431	validation_1-auc:0.83112
# [59]	validation_0-auc:0.83597	validation_1-auc:0.83259
# [60]	validation_0-auc:0.83600	validation_1-auc:0.83220
# [61]	validation_0-auc:0.83667	validation_1-auc:0.83287
# [62]	validation_0-auc:0.83681	validation_1-auc:0.83289
# [63]	validation_0-auc:0.83695	validation_1-auc:0.83269
# [64]	validation_0-auc:0.83703	validation_1-auc:0.83265
# [65]	validation_0-auc:0.83725	validation_1-auc:0.83246
# [66]	validation_0-auc:0.83851	validation_1-auc:0.83371
# [67]	validation_0-auc:0.83855	validation_1-auc:0.83359
# [68]	validation_0-auc:0.83974	validation_1-auc:0.83469
# [69]	validation_0-auc:0.84072	validation_1-auc:0.83555
# [70]	validation_0-auc:0.84097	validation_1-auc:0.83575
# [71]	validation_0-auc:0.84149	validation_1-auc:0.83596
# [72]	validation_0-auc:0.84193	validation_1-auc:0.83664
# [73]	validation_0-auc:0.84210	validation_1-auc:0.83657
# [74]	validation_0-auc:0.84248	validation_1-auc:0.83681
# [75]	validation_0-auc:0.84294	validation_1-auc:0.83752
# [76]	validation_0-auc:0.84325	validation_1-auc:0.83759
# [77]	validation_0-auc:0.84392	validation_1-auc:0.83818
# [78]	validation_0-auc:0.84398	validation_1-auc:0.83818
# [79]	validation_0-auc:0.84450	validation_1-auc:0.83883
# [80]	validation_0-auc:0.84471	validation_1-auc:0.83880
# [81]	validation_0-auc:0.84506	validation_1-auc:0.83893
# [82]	validation_0-auc:0.84519	validation_1-auc:0.83920
# [83]	validation_0-auc:0.84541	validation_1-auc:0.83934
# [84]	validation_0-auc:0.84561	validation_1-auc:0.83951
# [85]	validation_0-auc:0.84587	validation_1-auc:0.83983
# [86]	validation_0-auc:0.84607	validation_1-auc:0.83997
# [87]	validation_0-auc:0.84620	validation_1-auc:0.84008
# [88]	validation_0-auc:0.84627	validation_1-auc:0.84007
# [89]	validation_0-auc:0.84652	validation_1-auc:0.84041
# [90]	validation_0-auc:0.84679	validation_1-auc:0.84048
# [91]	validation_0-auc:0.84688	validation_1-auc:0.84066
# [92]	validation_0-auc:0.84699	validation_1-auc:0.84077
# [93]	validation_0-auc:0.84702	validation_1-auc:0.84103
# [94]	validation_0-auc:0.84720	validation_1-auc:0.84118
# [95]	validation_0-auc:0.84737	validation_1-auc:0.84132
# [96]	validation_0-auc:0.84747	validation_1-auc:0.84136
# [97]	validation_0-auc:0.84769	validation_1-auc:0.84150
# [98]	validation_0-auc:0.84784	validation_1-auc:0.84149
# [99]	validation_0-auc:0.84797	validation_1-auc:0.84172
# [100]	validation_0-auc:0.84805	validation_1-auc:0.84175
# [101]	validation_0-auc:0.84827	validation_1-auc:0.84184
# [102]	validation_0-auc:0.84857	validation_1-auc:0.84194
# [103]	validation_0-auc:0.84864	validation_1-auc:0.84195
# [104]	validation_0-auc:0.84872	validation_1-auc:0.84205
# [105]	validation_0-auc:0.84884	validation_1-auc:0.84212
# [106]	validation_0-auc:0.84898	validation_1-auc:0.84229
# [107]	validation_0-auc:0.84902	validation_1-auc:0.84229
# [108]	validation_0-auc:0.84905	validation_1-auc:0.84227
# [109]	validation_0-auc:0.84918	validation_1-auc:0.84241
# [110]	validation_0-auc:0.84928	validation_1-auc:0.84235
# [111]	validation_0-auc:0.84939	validation_1-auc:0.84246
# [112]	validation_0-auc:0.84954	validation_1-auc:0.84250
# [113]	validation_0-auc:0.84960	validation_1-auc:0.84250
# [114]	validation_0-auc:0.84987	validation_1-auc:0.84254
# [115]	validation_0-auc:0.84997	validation_1-auc:0.84252
# [116]	validation_0-auc:0.85006	validation_1-auc:0.84263
# [117]	validation_0-auc:0.85011	validation_1-auc:0.84262
# [118]	validation_0-auc:0.85036	validation_1-auc:0.84280
# [119]	validation_0-auc:0.85058	validation_1-auc:0.84286
# [120]	validation_0-auc:0.85064	validation_1-auc:0.84275
# [121]	validation_0-auc:0.85087	validation_1-auc:0.84283
# [122]	validation_0-auc:0.85100	validation_1-auc:0.84283
# [123]	validation_0-auc:0.85108	validation_1-auc:0.84280
# [124]	validation_0-auc:0.85114	validation_1-auc:0.84281
# [125]	validation_0-auc:0.85122	validation_1-auc:0.84278
# [126]	validation_0-auc:0.85133	validation_1-auc:0.84283
# [127]	validation_0-auc:0.85139	validation_1-auc:0.84283
# [128]	validation_0-auc:0.85149	validation_1-auc:0.84283
# [129]	validation_0-auc:0.85157	validation_1-auc:0.84281
# [130]	validation_0-auc:0.85160	validation_1-auc:0.84273
# [131]	validation_0-auc:0.85172	validation_1-auc:0.84281
# [132]	validation_0-auc:0.85184	validation_1-auc:0.84270
# [133]	validation_0-auc:0.85190	validation_1-auc:0.84276
# [134]	validation_0-auc:0.85194	validation_1-auc:0.84276
# [135]	validation_0-auc:0.85205	validation_1-auc:0.84281
# [136]	validation_0-auc:0.85223	validation_1-auc:0.84289
# [137]	validation_0-auc:0.85232	validation_1-auc:0.84291
# [138]	validation_0-auc:0.85235	validation_1-auc:0.84298
# [139]	validation_0-auc:0.85245	validation_1-auc:0.84304
# [140]	validation_0-auc:0.85258	validation_1-auc:0.84296
# [141]	validation_0-auc:0.85267	validation_1-auc:0.84288
# [142]	validation_0-auc:0.85273	validation_1-auc:0.84284
# [143]	validation_0-auc:0.85279	validation_1-auc:0.84289
# [144]	validation_0-auc:0.85288	validation_1-auc:0.84295
# [145]	validation_0-auc:0.85294	validation_1-auc:0.84297
# [146]	validation_0-auc:0.85300	validation_1-auc:0.84305
# [147]	validation_0-auc:0.85306	validation_1-auc:0.84303
# [148]	validation_0-auc:0.85313	validation_1-auc:0.84302
# [149]	validation_0-auc:0.85316	validation_1-auc:0.84301
# [150]	validation_0-auc:0.85326	validation_1-auc:0.84301
# [151]	validation_0-auc:0.85328	validation_1-auc:0.84298
# [152]	validation_0-auc:0.85335	validation_1-auc:0.84301
# [153]	validation_0-auc:0.85341	validation_1-auc:0.84304
# [154]	validation_0-auc:0.85369	validation_1-auc:0.84304
# [155]	validation_0-auc:0.85382	validation_1-auc:0.84317
# [156]	validation_0-auc:0.85384	validation_1-auc:0.84316
# [157]	validation_0-auc:0.85388	validation_1-auc:0.84317
# [158]	validation_0-auc:0.85392	validation_1-auc:0.84316
# [159]	validation_0-auc:0.85395	validation_1-auc:0.84316
# [160]	validation_0-auc:0.85402	validation_1-auc:0.84310
# [161]	validation_0-auc:0.85411	validation_1-auc:0.84303
# [162]	validation_0-auc:0.85416	validation_1-auc:0.84303
# [163]	validation_0-auc:0.85425	validation_1-auc:0.84298
# [164]	validation_0-auc:0.85430	validation_1-auc:0.84295
# [165]	validation_0-auc:0.85431	validation_1-auc:0.84296
# [166]	validation_0-auc:0.85437	validation_1-auc:0.84297
# [167]	validation_0-auc:0.85437	validation_1-auc:0.84295
# [168]	validation_0-auc:0.85443	validation_1-auc:0.84294
# [169]	validation_0-auc:0.85449	validation_1-auc:0.84292
# [170]	validation_0-auc:0.85454	validation_1-auc:0.84291
# [171]	validation_0-auc:0.85463	validation_1-auc:0.84300
# [172]	validation_0-auc:0.85472	validation_1-auc:0.84296
# [173]	validation_0-auc:0.85482	validation_1-auc:0.84292
# [174]	validation_0-auc:0.85498	validation_1-auc:0.84296
# [175]	validation_0-auc:0.85507	validation_1-auc:0.84299
# [176]	validation_0-auc:0.85517	validation_1-auc:0.84293
# [177]	validation_0-auc:0.85526	validation_1-auc:0.84292
# [178]	validation_0-auc:0.85529	validation_1-auc:0.84292
# [179]	validation_0-auc:0.85533	validation_1-auc:0.84290
# [180]	validation_0-auc:0.85542	validation_1-auc:0.84286
# [181]	validation_0-auc:0.85550	validation_1-auc:0.84291
# [182]	validation_0-auc:0.85555	validation_1-auc:0.84293
# [183]	validation_0-auc:0.85560	validation_1-auc:0.84290
# [184]	validation_0-auc:0.85566	validation_1-auc:0.84291
# [185]	validation_0-auc:0.85575	validation_1-auc:0.84301
# [186]	validation_0-auc:0.85589	validation_1-auc:0.84304
# [187]	validation_0-auc:0.85596	validation_1-auc:0.84301
# [188]	validation_0-auc:0.85604	validation_1-auc:0.84304
# [189]	validation_0-auc:0.85610	validation_1-auc:0.84299
# [190]	validation_0-auc:0.85627	validation_1-auc:0.84297
# [191]	validation_0-auc:0.85632	validation_1-auc:0.84291
# [192]	validation_0-auc:0.85637	validation_1-auc:0.84292
# [193]	validation_0-auc:0.85646	validation_1-auc:0.84292
# [194]	validation_0-auc:0.85651	validation_1-auc:0.84291
# [195]	validation_0-auc:0.85656	validation_1-auc:0.84290
# [196]	validation_0-auc:0.85660	validation_1-auc:0.84290
# [197]	validation_0-auc:0.85665	validation_1-auc:0.84283
# [198]	validation_0-auc:0.85680	validation_1-auc:0.84280
# [199]	validation_0-auc:0.85696	validation_1-auc:0.84285
# [200]	validation_0-auc:0.85701	validation_1-auc:0.84282
# [201]	validation_0-auc:0.85712	validation_1-auc:0.84284
# [202]	validation_0-auc:0.85717	validation_1-auc:0.84287
# [203]	validation_0-auc:0.85721	validation_1-auc:0.84286
# [204]	validation_0-auc:0.85723	validation_1-auc:0.84286
# [205]	validation_0-auc:0.85733	validation_1-auc:0.84286
# Overall AUC: 0.8495793322119303
# C:\Users\mega\AppData\Local\Temp\ipykernel_16496\587724534.py:170: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test['n0'] = (test == 0).sum(axis=1)
# C:\Users\mega\AppData\Local\Temp\ipykernel_16496\587724534.py:178: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test['PCA1'] = test_pca[:,0]
# C:\Users\mega\AppData\Local\Temp\ipykernel_16496\587724534.py:179: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   test['PCA2'] = test_pca[:,1]
